# %% [markdown]
# ## Target Schema

# %% [markdown]
# ![target_schema004.PNG](attachment:target_schema004.PNG)

# %% [markdown]
# # (A)   Import the dataset and do usual exploratory analysis steps like checking the structure & characteristics of the dataset
# 1. Data type of columns in a table
# 2. Time period for which the data is given
# 3. Cities and States covered in the dataset

# %% [markdown]
# ### 1. Data type of columns in a table

# %% [markdown]
# ![td001.PNG](attachment:td001.PNG)

# %% [markdown]
# ![td003.PNG](attachment:td003.PNG)

# %% [markdown]
# ### 2. Time period for which the data is given

# %% [markdown]
# ![td002.PNG](attachment:td002.PNG)

# %% [markdown]
# data is available from June 2016 to October 2018

# %% [markdown]
# ### 3. Cities and States covered in the dataset

# %% [markdown]
# customer cities and state

# %% [markdown]
# ![td004.PNG](attachment:td004.PNG)

# %% [markdown]
# ![td005.PNG](attachment:td005.PNG)

# %%
# Sao Paulo city occurs 15540 times in database

# %% [markdown]
# ![td006.PNG](attachment:td006.PNG)

# %% [markdown]
# ![td007.PNG](attachment:td007.PNG)

# %%
# SP state occurs 41746 times in database

# %% [markdown]
# sellers cities and state

# %% [markdown]
# ![td008.PNG](attachment:td008.PNG)

# %% [markdown]
# ![td009.PNG](attachment:td009.PNG)

# %% [markdown]
# ![td010.PNG](attachment:td010.PNG)

# %% [markdown]
# ![td011.PNG](attachment:td011.PNG)

# %% [markdown]
# # (B)    In-depth Exploration:
#
# 1. Is there a growing trend on e-commerce in Brazil? How can we describe a complete scenario? Can we see some seasonality with peaks at specific months?
#
# 2. What time do Brazilian customers tend to buy (Dawn, Morning, Afternoon or Night)?

# %%
# 1. Is there a growing trend on e-commerce in Brazil? How can we describe a complete scenario?

# %% [markdown]
# ![td012.PNG](attachment:td012.PNG)

# %%
# Can we see some seasonality with peaks at specific months?

# %% [markdown]
# ![td013.PNG](attachment:td013.PNG)

# %%
# 2. What time do Brazilian customers tend to buy (Dawn, Morning, Afternoon or Night)?

# %%
# Parts of the Day ; 
# Morning 4 am to 12 pm (noon) ; 
# Afternoon 12 pm to 5 pm ; 
# Evening 5 pm to 9 pm ; 
# Night 9 pm to 4 am.

# %% [markdown]
# ![td014.PNG](attachment:td014.PNG)

# %% [markdown]
# # (C)    Evolution of E-commerce orders in the Brazil region:
#
# 1. Get month on month orders by region, states
#
# 2. How are customers distributed in Brazil

# %%
# 1. Get month on month highest orders by region

# %% [markdown]
# ![td045.PNG](attachment:td045.PNG)

# %% [markdown]
# ![td046.PNG](attachment:td046.PNG)

# %% [markdown]
# ![td047.PNG](attachment:td047.PNG)

# %%
# 2. How are customers distributed in Brazil

# %% [markdown]
# ![td017.PNG](attachment:td017.PNG)

# %% [markdown]
# ![td018.PNG](attachment:td018.PNG)

# %%
# Distrbution of customers state wise in Brazil

# %% [markdown]
# # (D)    Impact on Economy: Analyze the money movemented by e-commerce by looking at order prices, freight and others.
#
# 1. Get % increase in cost of orders from 2017 to 2018 (include months between Jan to Aug only)
#
# 2. Mean & Sum of price and freight value by customer state

# %%
# 1. Get % increase in cost of orders from 2017 to 2018 (include months between Jan to Aug only)

# %% [markdown]
# ![td019.PNG](attachment:td019.PNG)

# %%
# 2. Mean & Sum of price and freight value by customer state

# %% [markdown]
# ![td020.PNG](attachment:td020.PNG)

# %% [markdown]
# ![td021.PNG](attachment:td021.PNG)

# %% [markdown]
# # (E)    Analysis on sales, freight and delivery time
#
# 1. Calculate days between purchasing, delivering and estimated delivery
#
# 2. Create columns:
#
#     2a. time_to_delivery = order_purchase_timestamp - order_delivered_customer_date
#
#     2b. diff_estimated_delivery = order_estimated_delivery_date - order_delivered_customer_date
#
# 3. Group data by state, take mean of freight_value, time_to_delivery, diff_estimated_delivery
#
# 4. Sort the data to get the following:
#
#     4a. Top 5 states with highest/lowest average freight value - sort in desc/asc limit 5
#
#     4b. Top 5 states with highest/lowest average time to delivery
#
#     4c. Top 5 states where delivery is really fast/ not so fast compared to estimated date

# %% [markdown]
# #### 1.  Calculate days between purchasing, delivering and estimated delivery

# %% [markdown]
# ![td022.PNG](attachment:td022.PNG)

# %% [markdown]
# ![td023.PNG](attachment:td023.PNG)

# %% [markdown]
# #### 2. Create columns:
#
#     2a. time_to_delivery = order_purchase_timestamp - order_delivered_customer_date
#
#     2b. diff_estimated_delivery = order_estimated_delivery_date - order_delivered_customer_date

# %% [markdown]
# ![td025.PNG](attachment:td025.PNG)

# %% [markdown]
# #### 3. Group data by state, take mean of freight_value, time_to_delivery, diff_estimated_delivery

# %% [markdown]
# ![td026.PNG](attachment:td026.PNG)

# %% [markdown]
# ![td027.PNG](attachment:td027.PNG)

# %% [markdown]
# #### 4. Sort the data to get the following:
#
#     4a. Top 5 states with highest/lowest average freight value - sort in desc/asc limit 5
#
#     4b. Top 5 states with highest/lowest average time to delivery
#
#     4c. Top 5 states where delivery is really fast/ not so fast compared to estimated date

# %%
# 4a. Top 5 states with highest average freight value - sort in desc limit 5

# %% [markdown]
# ![TD028.PNG](attachment:TD028.PNG)

# %% [markdown]
# ![td029.PNG](attachment:td029.PNG)

# %%
# 4a. Top 5 states with lowest average freight value - sort in asc limit 5

# %% [markdown]
# ![td032.PNG](attachment:td032.PNG)

# %% [markdown]
# ![td031.PNG](attachment:td031.PNG)

# %%
# 4b. Top 5 states with highest average time to delivery

# %% [markdown]
# ![td033.PNG](attachment:td033.PNG)

# %% [markdown]
# ![td034.PNG](attachment:td034.PNG)

# %%
# 4b. Top 5 states with lowest average time to delivery

# %% [markdown]
# ![td035.PNG](attachment:td035.PNG)

# %% [markdown]
# ![td036.PNG](attachment:td036.PNG)

# %%
# 4c. Top 5 states where delivery is really fast compared to estimated date

# %% [markdown]
# ![td037.PNG](attachment:td037.PNG)

# %% [markdown]
# ![td038.PNG](attachment:td038.PNG)

# %%
# 4c. Top 5 states where delivery is not so fast compared to estimated date

# %% [markdown]
# ![td039.PNG](attachment:td039.PNG)

# %% [markdown]
# ![td040.PNG](attachment:td040.PNG)

# %% [markdown]
# # (F)    Payment type analysis:
#
# 1. Month over Month count of orders for different payment types
#
# 2. Distribution of payment installments and count of orders

# %%
# 1. Month over Month count of orders for different payment types

# %% [markdown]
# ![td041.PNG](attachment:td041.PNG)

# %% [markdown]
# ![td042.PNG](attachment:td042.PNG)

# %% [markdown]
# ![td043.PNG](attachment:td043.PNG)

# %% [markdown]
# ![td044.PNG](attachment:td044.PNG)

# %%
# 2.  Distribution of payment installments and count of orders

# %% [markdown]
# ![td048.PNG](attachment:td048.PNG)

# %% [markdown]
# ![td049.PNG](attachment:td049.PNG)
